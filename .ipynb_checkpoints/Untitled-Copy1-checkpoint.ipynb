# %%
import pandas as pd
from matplotlib import pyplot as plt
import datetime as datetime
import numpy as np
import json
import os
from statistics import mean, median

# %%
pasta = "1_res_fuzzy_en0_dataset_artigo_marcos_filipe1.xlsx"
excel = pd.read_excel(pasta, sheet_name='res_fuzzy_en0', header=0, engine='openpyxl')

# %%
excel
# Out:
#        Dia  Mês  Hora_U  Minuto       Hora  E_Total_KWh  Eg_KWh  PAC_W  \
# 0        2    1      17      30  17.500000          0.0     0.0    0.0
# 1        2    1      17      35  17.583333          0.0     0.0    0.0
# 2        2    1      17      40  17.666667          0.0     0.0    0.0
# 3        2    1      17      45  17.750000          0.0     0.0    0.0
# 4        2    1      17      50  17.833333          0.0     0.0    0.0
# ...    ...  ...     ...     ...        ...          ...     ...    ...
# 96698   31   12      23      35  23.583333          0.0     0.0    0.0
# 96699   31   12      23      40  23.666667          0.0     0.0    0.0
# 96700   31   12      23      45  23.750000          0.0     0.0    0.0
# 96701   31   12      23      50  23.833333          0.0     0.0    0.0
# 96702   31   12      23      55  23.916667          0.0     0.0    0.0
#
#               Eg_KW    Ec_KWh  ...    E_grid  E_rede_2  E_consumo_1  \
# 0      1.272555e-02  0.676351  ...  0.012726 -2.692678     0.012726
# 1      1.401694e-02  0.676351  ...  0.014017 -2.691387     0.014017
# 2      1.016037e-02  0.676351  ...  0.010160 -2.695244     0.010160
# 3      5.022936e-03  0.522741  ...  0.005023 -2.085941     0.005023
# 4      2.930837e-03  0.522741  ...  0.002931 -2.088033     0.002931
# ...             ...       ...  ...       ...       ...          ...
# 96698  3.604511e-09  0.109415  ...  0.000679 -0.436981     0.000679
# 96699  8.751030e-10  0.109415  ...  0.000679 -0.436981     0.000679
# 96700  7.225747e-10  0.090612  ...  0.000562 -0.361886     0.000562
# 96701  2.472981e-08  0.090612  ...  0.000562 -0.361886     0.000562
# 96702  3.519357e-05  0.090612  ...  0.000598 -0.361850     0.000598
#
#        E_consumo_2  E_consumida_n    Fatura  Fatura_Simples       Data  \
# 0         2.705404      -0.224390 -0.177268        0.178106 2013-01-02
# 1         2.705404      -0.224282 -0.177183        0.178106 2013-01-02
# 2         2.705404      -0.224604 -0.177437        0.178106 2013-01-02
# 3         2.090964      -0.173828 -0.137324        0.137655 2013-01-02
# 4         2.090964      -0.174003 -0.137462        0.137655 2013-01-02
# ...            ...            ...       ...             ...        ...
# 96698     0.437660      -0.036415 -0.017479        0.017506 2013-12-31
# 96699     0.437660      -0.036415 -0.017479        0.017506 2013-12-31
# 96700     0.362448      -0.030157 -0.014475        0.014498 2013-12-31
# 96701     0.362448      -0.030157 -0.014475        0.014498 2013-12-31
# 96702     0.362448      -0.030154 -0.014474        0.014498 2013-12-31
#
#          Hora_H            Datetime
# 0      17:30:00 2013-01-02 17:30:00
# 1      17:35:00 2013-01-02 17:35:00
# 2      17:40:00 2013-01-02 17:40:00
# 3      17:45:00 2013-01-02 17:45:00
# 4      17:50:00 2013-01-02 17:50:00
# ...         ...                 ...
# 96698  23:35:00 2013-12-31 23:35:00
# 96699  23:40:00 2013-12-31 23:40:00
# 96700  23:45:00 2013-12-31 23:45:00
# 96701  23:50:00 2013-12-31 23:50:00
# 96702  23:55:00 2013-12-31 23:55:00
#
# [96703 rows x 28 columns]

# %%
from sklearn.preprocessing import MinMaxScaler


def save_to_npy(df, filename):
    
    df = df.copy()

    scaler = MinMaxScaler()
    df['P'] = scaler.fit_transform(np.array(df['P']).reshape(-1, 1))
    
    # TRANSFORMA NO FORMATO ADEQUADO O DATAFRAME PARA SER ENTRADA DA SRGAN
    lista_dates = df['date'].unique().tolist()
    
    dic = {}

    for d in lista_dates:
        dic[d] = df.loc[df['date'] == d]['P'].tolist()

    df_datesC = pd.DataFrame(dic)
    
    data_array = df_datesC.to_numpy()
    
    # TRANSFORMA TODOS OS VALORES PARA NUMEROS ENTRE 0 E 1
    # scaler = MinMaxScaler(copy=False)
    # scaler.fit_transform(data_array)
    
    data_array = np.transpose(data_array)
    
    print(data_array[0])
    
        
    np.save("SRGAN_power_data_generation-main/data/"+ filename + 'test_pv_3600', data_array)

    return scaler

# %%
#EXECUTAR SRGAN

# %%
def load_result(filename, scaler, df):
    df = df.copy()
    dates_list = df['date'].unique().tolist()
    
    datetime_list = []
    res = np.load(filename)
    
    delta = datetime.timedelta(minutes=5)
    for d in dates_list:
        datetime_atual = datetime.datetime(year= d.year, month= d.month, day= d.day)
        while (datetime_atual.month == d.month and datetime_atual.day == d.day):
            datetime_list.append(datetime_atual)
            datetime_atual = datetime_atual + delta
    
    # res = np.transpose(res)
    # scaler.inverse_transform(res)
    # res = np.transpose(res)
    
    res = np.reshape(res, df.shape[0]*12)
    
    new_df = pd.DataFrame(data = {'datetime': datetime_list, 'P': res})
    
    new_df['P'] = scaler.inverse_transform(np.array(new_df['P']).reshape(-1, 1))
    return new_df

# %%
import datetime
def ajuste_datetime(df, column, horas):
    df['datetime'] = pd.to_datetime(df[column], format='%Y%m%d:%H%M')
    delta = datetime.timedelta(hours = horas)
    df['datetime'] = df['datetime'] - delta
    
    df = df.iloc[horas:]
    df.reset_index(drop=True, inplace=True)
    
    for i in range(horas):
        df.loc[len(df)] = {'time': '0', 'P': 0, 'datetime': df.datetime.iloc[-1] + datetime.timedelta(hours=1) }
    
    
    df['date'] = df['datetime'].dt.date
    
    return df

# %%
path_of_the_directory= 'pvgis_files'
values = {'scaler': [], 'df': []}

fusos = [4, 4, 3, 3, 3, 1]

scalers = []

print("Files and directories in a specified path:")
for filename in os.listdir(path_of_the_directory):
    f = os.path.join(path_of_the_directory,filename)
    if os.path.isfile(f):
        with open(f, 'r') as json_file:
            json_load = json.load(json_file)
                  
        print(f)
        df = pd.json_normalize(json_load['outputs']['hourly'])
        df = df[['time', 'P']]
        df = ajuste_datetime(df, 'time', fusos[0])
        fusos.pop(0)

        
        print(df.head(20))
        print(df.tail(7))
        
        values['scaler'].append(save_to_npy(df, filename))
        values['df'].append(df)
# Out:
# Files and directories in a specified path:
# pvgis_files\belem_SA2_2kWp_2013.json
# C:\Users\Carol\AppData\Local\Temp\ipykernel_15984\449282226.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[len(df)] = {'time': '0', 'P': 0, 'datetime': df.datetime.iloc[-1] + datetime.timedelta(hours=1) }
# C:\Users\Carol\AppData\Local\Temp\ipykernel_15984\449282226.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[len(df)] = {'time': '0', 'P': 0, 'datetime': df.datetime.iloc[-1] + datetime.timedelta(hours=1) }
# C:\Users\Carol\AppData\Local\Temp\ipykernel_15984\449282226.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[len(df)] = {'time': '0', 'P': 0, 'datetime': df.datetime.iloc[-1] + datetime.timedelta(hours=1) }
#                time    P            datetime        date
# 8753  20131231:1810  0.0 2013-12-31 17:10:00  2013-12-31
# 8754  20131231:1910  0.0 2013-12-31 18:10:00  2013-12-31
# 8755  20131231:2010  0.0 2013-12-31 19:10:00  2013-12-31
# 8756  20131231:2110  0.0 2013-12-31 20:10:00  2013-12-31
# 8757  20131231:2210  0.0 2013-12-31 21:10:00  2013-12-31
# 8758  20131231:2310  0.0 2013-12-31 22:10:00  2013-12-31
# 8759              0  0.0 2013-12-31 23:10:00  2013-12-31
# [0.         0.         0.         0.         0.         0.
#  0.         0.         0.3058676  0.33404006 0.56914699 0.74467412
#  0.49166802 0.61433365 0.17033776 0.16194741 0.         0.
#  0.         0.         0.         0.         0.         0.        ]

# %%
for i in values:
    print(i, values[i])
# Out:
# belem_SA2_2kWp_2013.json {'max': 2446.91, 'date': datetime.date(2013, 1, 1), 'media': 780.9958333333333, 'mediana': 41.705}
# cuiaba_htrue_SA2_2kWp_2013.json {'max': 2377.52, 'date': datetime.date(2013, 1, 1), 'media': 768.4491666666667, 'mediana': 132.04}
# portoalegre_htrue_SA2_2kWp_2013.json {'max': 2592.17, 'date': datetime.date(2013, 1, 1), 'media': 850.9266666666666, 'mediana': 182.235}
# recife_SA2_2kWp_2013.json {'max': 2580.06, 'date': datetime.date(2013, 1, 1), 'media': 870.8220833333334, 'mediana': 99.905}
# saopaulo_htrue_SA2_2kWp_2013.json {'max': 2495.19, 'date': datetime.date(2013, 1, 1), 'media': 817.495, 'mediana': 153.61}
# Timeseries_41.154_-8.591_SA2_2kWp_crystSi_0_34deg_1deg_2013_2013.json {'max': 2655.43, 'date': datetime.date(2013, 1, 1), 'media': 860.8829166666667, 'mediana': 230.06}

# %%
# Executar SRGAN

# %%
path_of_the_directory= 'SRGAN_power_data_generation-main/results'

print("Files and directories in a specified path:")
for filename in os.listdir(path_of_the_directory):
    f = os.path.join(path_of_the_directory,filename)
    if os.path.isfile(f):
    
        print(f)
        
        dataframe = load_result('SRGAN_power_data_generation-main/results/'+ filename, values['scaler'][0], values['df'][0])
        
        values['df'].pop(0)
        values['scaler'].pop(0)
        
        display(dataframe)
        
        print(dataframe['P'].max(), dataframe['P'].mean())
        
        plt.figure(figsize=(10, 3), dpi=120)
        dataframe['P'].plot()
        plt.show()
        
        dataframe.to_csv('result_interp/'+filename[:-15]+'.csv')
        
        
        '''
        name = filename.removesuffix('.jsonresult.npy')
        textfile = open(('txts/'+name + "_prod_kwatts.txt"), "w")
        
        for datas in excel['Datetime']:
            element = dataframe.loc[dataframe['datetime'] == datas].iloc[0]['prod']
            textfile.write(str(element).upper().replace('.', ',', 1) + "\n")
        textfile.close()
        '''
#         rslt_df = dataframe.loc[dataframe['datetime'].isin(excel['Datetime'])]
        
        
#         name = filename.removesuffix('.jsonresult.npy')
#         textfile = open(('txts/'+name + "_prod_kwatts.txt"), "w")
        
#         for element in rslt_df['prod']:
#             textfile.write(str(element).upper().replace('.', ',', 1) + "\n")
#         textfile.close()
# Out:
# Files and directories in a specified path:
# SRGAN_power_data_generation-main/results\belem_SA2_2kWp_2013.jsonresult.npy
#                   datetime             P
# 0      2013-01-01 00:00:00  2.734144e-12
# 1      2013-01-01 00:05:00  4.067943e-21
# 2      2013-01-01 00:10:00  1.934716e-24
# 3      2013-01-01 00:15:00  6.910633e-26
# 4      2013-01-01 00:20:00  5.167556e-27
# ...                    ...           ...
# 105115 2013-12-31 23:35:00  3.498537e-09
# 105116 2013-12-31 23:40:00  6.912327e-09
# 105117 2013-12-31 23:45:00  1.274420e-09
# 105118 2013-12-31 23:50:00  9.452159e-09
# 105119 2013-12-31 23:55:00  2.841366e-04
#
# [105120 rows x 2 columns]
# 2432.111572265625 519.9560546875
# SRGAN_power_data_generation-main/results\cuiaba_htrue_SA2_2kWp_2013.jsonresult.npy
#                   datetime             P
# 0      2013-01-01 00:00:00  3.380938e-11
# 1      2013-01-01 00:05:00  2.126692e-16
# 2      2013-01-01 00:10:00  5.531329e-15
# 3      2013-01-01 00:15:00  3.152719e-12
# 4      2013-01-01 00:20:00  1.034008e-12
# ...                    ...           ...
# 105115 2013-12-31 23:35:00  1.483177e-06
# 105116 2013-12-31 23:40:00  6.687857e-07
# 105117 2013-12-31 23:45:00  7.831077e-07
# 105118 2013-12-31 23:50:00  4.854100e-05
# 105119 2013-12-31 23:55:00  3.501644e-02
#
# [105120 rows x 2 columns]
# 2312.726318359375 484.8125305175781
# SRGAN_power_data_generation-main/results\portoalegre_htrue_SA2_2kWp_2013.jsonresult.npy
#                   datetime             P
# 0      2013-01-01 00:00:00  2.382875e-10
# 1      2013-01-01 00:05:00  7.584859e-18
# 2      2013-01-01 00:10:00  1.331285e-19
# 3      2013-01-01 00:15:00  4.531265e-20
# 4      2013-01-01 00:20:00  3.158329e-20
# ...                    ...           ...
# 105115 2013-12-31 23:35:00  2.537715e-17
# 105116 2013-12-31 23:40:00  4.484655e-16
# 105117 2013-12-31 23:45:00  3.425483e-13
# 105118 2013-12-31 23:50:00  4.513812e-10
# 105119 2013-12-31 23:55:00  3.664971e-04
#
# [105120 rows x 2 columns]
# 2518.79248046875 472.9493103027344
# SRGAN_power_data_generation-main/results\recife_SA2_2kWp_2013.jsonresult.npy
#                   datetime             P
# 0      2013-01-01 00:00:00  1.152117e-09
# 1      2013-01-01 00:05:00  5.497745e-15
# 2      2013-01-01 00:10:00  5.629085e-16
# 3      2013-01-01 00:15:00  2.924668e-15
# 4      2013-01-01 00:20:00  1.137427e-16
# ...                    ...           ...
# 105115 2013-12-31 23:35:00  1.629793e-07
# 105116 2013-12-31 23:40:00  2.510933e-07
# 105117 2013-12-31 23:45:00  7.532074e-08
# 105118 2013-12-31 23:50:00  4.007152e-07
# 105119 2013-12-31 23:55:00  1.918658e-03
#
# [105120 rows x 2 columns]
# 2540.173583984375 624.9369506835938
# SRGAN_power_data_generation-main/results\saopaulo_htrue_SA2_2kWp_2013.jsonresult.npy
#                   datetime             P
# 0      2013-01-01 00:00:00  1.337238e-09
# 1      2013-01-01 00:05:00  1.994920e-16
# 2      2013-01-01 00:10:00  1.546878e-19
# 3      2013-01-01 00:15:00  2.788515e-21
# 4      2013-01-01 00:20:00  6.712302e-22
# ...                    ...           ...
# 105115 2013-12-31 23:35:00  6.991693e-11
# 105116 2013-12-31 23:40:00  5.788421e-10
# 105117 2013-12-31 23:45:00  1.926328e-09
# 105118 2013-12-31 23:50:00  1.970826e-08
# 105119 2013-12-31 23:55:00  1.133350e-03
#
# [105120 rows x 2 columns]
# 2461.658447265625 441.24383544921875
# SRGAN_power_data_generation-main/results\Timeseries_41.154_-8.591_SA2_2kWp_crystSi_0_34deg_1deg_2013_2013.jsonresult.npy
#                   datetime             P
# 0      2013-01-01 00:00:00  9.560022e-11
# 1      2013-01-01 00:05:00  1.162096e-18
# 2      2013-01-01 00:10:00  2.962951e-23
# 3      2013-01-01 00:15:00  5.895915e-27
# 4      2013-01-01 00:20:00  1.631693e-28
# ...                    ...           ...
# 105115 2013-12-31 23:35:00  1.401894e-20
# 105116 2013-12-31 23:40:00  8.363915e-19
# 105117 2013-12-31 23:45:00  2.472805e-17
# 105118 2013-12-31 23:50:00  2.064377e-13
# 105119 2013-12-31 23:55:00  3.184209e-07
#
# [105120 rows x 2 columns]
# 2628.804443359375 499.93359375

# %%
import datetime
df = pd.read_excel('privatehome6.xls', sheet_name='Trend')

# %%
df['Hour'] = df['Hour'].apply(lambda x: str(x)[-8:])

# %%
df[df.Hour == '00:00:00']
# Out:
#              Day  Year  Month  Week  Week Day      Hour       kWh        kW
# 95    2011-12-26  2011     12    53         1  00:00:00  0.450760  1.803040
# 191   2011-12-27  2011     12    53         2  00:00:00  0.738353  2.953412
# 287   2011-12-28  2011     12    53         3  00:00:00  0.554530  2.218120
# 383   2011-12-29  2011     12    53         4  00:00:00  0.267444  1.069776
# 479   2011-12-30  2011     12    53         5  00:00:00  0.314615  1.258460
# ...          ...   ...    ...   ...       ...       ...       ...       ...
# 42336 2013-03-11  2013      3    11         1  00:00:00  0.206745  0.826980
# 42432 2013-03-12  2013      3    11         2  00:00:00  0.223322  0.893288
# 42528 2013-03-13  2013      3    11         3  00:00:00  0.373589  1.494356
# 42624 2013-03-14  2013      3    11         4  00:00:00  0.346125  1.384500
# 42720 2013-03-15  2013      3    11         5  00:00:00  0.139073  0.556292
#
# [446 rows x 8 columns]

# %%
df.loc[df.Hour == '00:00:00', 'Day'] = df.Day + datetime.timedelta(days=1)

# %%
df.head(99)
# Out:
#            Day  Year  Month  Week  Week Day      Hour       kWh        kW
# 671 2012-01-01  2011     12    53         7  00:00:00  0.095168  0.380672
# 672 2012-01-01  2012      1     1         1  00:15:00  0.113863  0.455452
# 673 2012-01-01  2012      1     1         1  00:30:00  0.092348  0.369392
# 674 2012-01-01  2012      1     1         1  00:45:00  0.183265  0.733060
# 675 2012-01-01  2012      1     1         1  01:00:00  0.211594  0.846376
# ..         ...   ...    ...   ...       ...       ...       ...       ...
# 765 2012-01-01  2012      1     1         1  23:30:00  0.422291  1.689164
# 766 2012-01-01  2012      1     1         1  23:45:00  0.360796  1.443184
# 767 2012-01-02  2012      1     1         1  00:00:00  0.218251  0.873004
# 768 2012-01-02  2012      1     1         2  00:15:00  0.271744  1.086976
# 769 2012-01-02  2012      1     1         2  00:30:00  0.222902  0.891608
#
# [99 rows x 8 columns]

# %%
df = df[df.Day.dt.year == 2012]

# %%
df.Hour.value_counts().values
# Out:
# array([366, 366, 366, 366, 366, 366, 366, 366, 366, 366, 366, 366, 366,
#        366, 366, 366, 366, 366, 366, 366, 366, 366, 366, 366, 366, 366,
#        366, 366, 366, 366, 366, 366, 366, 366, 366, 366, 366, 366, 366,
#        366, 366, 366, 366, 366, 366, 366, 366, 366, 366, 366, 366, 366,
#        366, 366, 366, 366, 366, 366, 366, 366, 366, 366, 366, 366, 366,
#        366, 366, 366, 366, 366, 366, 366, 366, 366, 366, 366, 366, 366,
#        366, 366, 366, 366, 366, 366, 366, 366, 366, 366, 366, 366, 366,
#        366, 366, 366, 366, 366], dtype=int64)

# %%
df['datetime'] = df['Day'].astype(str) + ' ' + df['Hour'].astype(str)
df['datetime'] = pd.to_datetime(df['datetime'])

# %%
df
# Out:
#              Day  Year  Month  Week  Week Day      Hour       kWh        kW  \
# 671   2012-01-01  2011     12    53         7  00:00:00  0.095168  0.380672
# 672   2012-01-01  2012      1     1         1  00:15:00  0.113863  0.455452
# 673   2012-01-01  2012      1     1         1  00:30:00  0.092348  0.369392
# 674   2012-01-01  2012      1     1         1  00:45:00  0.183265  0.733060
# 675   2012-01-01  2012      1     1         1  01:00:00  0.211594  0.846376
# ...          ...   ...    ...   ...       ...       ...       ...       ...
# 35802 2012-12-31  2012     12    53         2  22:45:00  0.100284  0.401136
# 35803 2012-12-31  2012     12    53         2  23:00:00  0.098439  0.393756
# 35804 2012-12-31  2012     12    53         2  23:15:00  0.096316  0.385264
# 35805 2012-12-31  2012     12    53         2  23:30:00  0.109415  0.437660
# 35806 2012-12-31  2012     12    53         2  23:45:00  0.090612  0.362448
#
#                  datetime
# 671   2012-01-01 00:00:00
# 672   2012-01-01 00:15:00
# 673   2012-01-01 00:30:00
# 674   2012-01-01 00:45:00
# 675   2012-01-01 01:00:00
# ...                   ...
# 35802 2012-12-31 22:45:00
# 35803 2012-12-31 23:00:00
# 35804 2012-12-31 23:15:00
# 35805 2012-12-31 23:30:00
# 35806 2012-12-31 23:45:00
#
# [35136 rows x 9 columns]

# %%
df = pd.concat([df, df, df])

# %%
df.sort_values(by=['datetime'], inplace = True)

# %%
df.head(80)
# Out:
#            Day  Year  Month  Week  Week Day      Hour       kWh        kW  \
# 671 2012-01-01  2011     12    53         7  00:00:00  0.095168  0.380672
# 671 2012-01-01  2011     12    53         7  00:00:00  0.095168  0.380672
# 671 2012-01-01  2011     12    53         7  00:00:00  0.095168  0.380672
# 672 2012-01-01  2012      1     1         1  00:15:00  0.113863  0.455452
# 672 2012-01-01  2012      1     1         1  00:15:00  0.113863  0.455452
# ..         ...   ...    ...   ...       ...       ...       ...       ...
# 696 2012-01-01  2012      1     1         1  06:15:00  0.039032  0.156128
# 696 2012-01-01  2012      1     1         1  06:15:00  0.039032  0.156128
# 696 2012-01-01  2012      1     1         1  06:15:00  0.039032  0.156128
# 697 2012-01-01  2012      1     1         1  06:30:00  0.142277  0.569108
# 697 2012-01-01  2012      1     1         1  06:30:00  0.142277  0.569108
#
#                datetime
# 671 2012-01-01 00:00:00
# 671 2012-01-01 00:00:00
# 671 2012-01-01 00:00:00
# 672 2012-01-01 00:15:00
# 672 2012-01-01 00:15:00
# ..                  ...
# 696 2012-01-01 06:15:00
# 696 2012-01-01 06:15:00
# 696 2012-01-01 06:15:00
# 697 2012-01-01 06:30:00
# 697 2012-01-01 06:30:00
#
# [80 rows x 9 columns]

# %%
for i in range(356):
    for i in range(24):

# %%
df.Hour.value_counts().values
# Out:
# array([1098, 1098, 1098, 1098, 1098, 1098, 1098, 1098, 1098, 1098, 1098,
#        1098, 1098, 1098, 1098, 1098, 1098, 1098, 1098, 1098, 1098, 1098,
#        1098, 1098, 1098, 1098, 1098, 1098, 1098, 1098, 1098, 1098, 1098,
#        1098, 1098, 1098, 1098, 1098, 1098, 1098, 1098, 1098, 1098, 1098,
#        1098, 1098, 1098, 1098, 1098, 1098, 1098, 1098, 1098, 1098, 1098,
#        1098, 1098, 1098, 1098, 1098, 1098, 1098, 1098, 1098, 1098, 1098,
#        1098, 1098, 1098, 1098, 1098, 1098, 1098, 1098, 1098, 1098, 1098,
#        1098, 1098, 1098, 1098, 1098, 1098, 1098, 1098, 1098, 1098, 1098,
#        1098, 1098, 1098, 1098, 1098, 1098, 1098, 1098], dtype=int64)
